# %% [markdown]
# # GPU Training Notebook
#
# This notebook allows us to train our model using a GPU.
#
# **Note:** Since the *HubroHub* environment is shared with other students, please remember to stop all GPU processes when your training is complete.
#
# ## Install Python Libraries
#
# Start by running the following cell to install required libraries:

# %%
# !pip install datasets tokenizers
# Out:
# Requirement already satisfied: datasets in C:\Users\nicol\anaconda3\envs\INF265\Lib\site-packages (4.5.0)
# Requirement already satisfied: tokenizers in C:\Users\nicol\anaconda3\envs\INF265\Lib\site-packages (0.22.2)
# Requirement already satisfied: filelock in C:\Users\nicol\anaconda3\envs\INF265\Lib\site-packages (from datasets) (3.20.3)
# Requirement already satisfied: numpy>=1.17 in C:\Users\nicol\anaconda3\envs\INF265\Lib\site-packages (from datasets) (2.0.1)
# Requirement already satisfied: pyarrow>=21.0.0 in C:\Users\nicol\anaconda3\envs\INF265\Lib\site-packages (from datasets) (23.0.1)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in C:\Users\nicol\anaconda3\envs\INF265\Lib\site-packages (from datasets) (0.4.0)
# Requirement already satisfied: pandas in C:\Users\nicol\anaconda3\envs\INF265\Lib\site-packages (from datasets) (2.3.3)
# Requirement already satisfied: requests>=2.32.2 in C:\Users\nicol\anaconda3\envs\INF265\Lib\site-packages (from datasets) (2.32.5)
# Requirement already satisfied: httpx<1.0.0 in C:\Users\nicol\anaconda3\envs\INF265\Lib\site-packages (from datasets) (0.28.1)
# Requirement already satisfied: tqdm>=4.66.3 in C:\Users\nicol\anaconda3\envs\INF265\Lib\site-packages (from datasets) (4.67.3)
# Requirement already satisfied: xxhash in C:\Users\nicol\anaconda3\envs\INF265\Lib\site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.19 in C:\Users\nicol\anaconda3\envs\INF265\Lib\site-packages (from datasets) (0.70.18)
# Requirement already satisfied: fsspec<=2025.10.0,>=2023.1.0 in C:\Users\nicol\anaconda3\envs\INF265\Lib\site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2025.10.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in C:\Users\nicol\anaconda3\envs\INF265\Lib\site-packages (from datasets) (1.4.1)
# Requirement already satisfied: packaging in C:\Users\nicol\anaconda3\envs\INF265\Lib\site-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in C:\Users\nicol\anaconda3\envs\INF265\Lib\site-packages (from datasets) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in C:\Users\nicol\anaconda3\envs\INF265\Lib\site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (3.13.3)
# Requirement already satisfied: anyio in C:\Users\nicol\anaconda3\envs\INF265\Lib\site-packages (from httpx<1.0.0->datasets) (4.12.1)
# Requirement already satisfied: certifi in C:\Users\nicol\anaconda3\envs\INF265\Lib\site-packages (from httpx<1.0.0->datasets) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in C:\Users\nicol\anaconda3\envs\INF265\Lib\site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in C:\Users\nicol\anaconda3\envs\INF265\Lib\site-packages (from httpx<1.0.0->datasets) (3.11)
# Requirement already satisfied: h11>=0.16 in C:\Users\nicol\anaconda3\envs\INF265\Lib\site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in C:\Users\nicol\anaconda3\envs\INF265\Lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.2.0)
# Requirement already satisfied: shellingham in C:\Users\nicol\anaconda3\envs\INF265\Lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.5.4)
# Requirement already satisfied: typer-slim in C:\Users\nicol\anaconda3\envs\INF265\Lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (0.24.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in C:\Users\nicol\anaconda3\envs\INF265\Lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (4.15.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\Users\nicol\anaconda3\envs\INF265\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\Users\nicol\anaconda3\envs\INF265\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\nicol\anaconda3\envs\INF265\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Users\nicol\anaconda3\envs\INF265\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Users\nicol\anaconda3\envs\INF265\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in C:\Users\nicol\anaconda3\envs\INF265\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Users\nicol\anaconda3\envs\INF265\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\nicol\anaconda3\envs\INF265\Lib\site-packages (from requests>=2.32.2->datasets) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\nicol\anaconda3\envs\INF265\Lib\site-packages (from requests>=2.32.2->datasets) (2.6.3)
# Requirement already satisfied: colorama in C:\Users\nicol\anaconda3\envs\INF265\Lib\site-packages (from tqdm>=4.66.3->datasets) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\nicol\anaconda3\envs\INF265\Lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\nicol\anaconda3\envs\INF265\Lib\site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\nicol\anaconda3\envs\INF265\Lib\site-packages (from pandas->datasets) (2025.3)
# Requirement already satisfied: six>=1.5 in C:\Users\nicol\anaconda3\envs\INF265\Lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: typer>=0.24.0 in C:\Users\nicol\anaconda3\envs\INF265\Lib\site-packages (from typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (0.24.0)
# Collecting click>=8.2.1 (from typer>=0.24.0->typer-slim->huggingface-hub<2.0,>=0.25.0->datasets)
#   Downloading click-8.3.3-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: rich>=12.3.0 in C:\Users\nicol\anaconda3\envs\INF265\Lib\site-packages (from typer>=0.24.0->typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (14.3.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\Users\nicol\anaconda3\envs\INF265\Lib\site-packages (from typer>=0.24.0->typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\nicol\anaconda3\envs\INF265\Lib\site-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\nicol\anaconda3\envs\INF265\Lib\site-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\nicol\anaconda3\envs\INF265\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (0.1.2)
# Downloading click-8.3.3-py3-none-any.whl (110 kB)
# Installing collected packages: click
#   Attempting uninstall: click
#     Found existing installation: click 7.1.2
#     Uninstalling click-7.1.2:
#       Successfully uninstalled click-7.1.2
# Successfully installed click-8.3.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# streamlit 1.9.0 requires click<8.1,>=7.0, but you have click 8.3.3 which is incompatible.

# %% [markdown]
# ## Imports
#
# Run the following cell to import the necessary files and review the configuration.

# %%
from pathlib import Path
from tokenizer import train_tokenizer
from train import train_model
from config import config
from utils import print_config

print_config(config)
# Out:
# Using configuration:
# 	seed: 0
# 	dataset: gooaq_subset
# 	split: train
# 	device: cuda
# 	vocab_size: 20000
# 	min_frequency: 5
# 	unk_token: [UNK]
# 	sep_token: [SEP]
# 	end_token: [END]
# 	pad_token: [PAD]
# 	tokenizer_filename: temp/tokenizer.json
# 	embed_size: 512
# 	num_heads: 8
# 	num_layers: 5
# 	dropout_p: 0.1
# 	max_len: 128
# 	model_train_fraction: 1.0
# 	batch_size: 128
# 	dataloader_num_workers: 2
# 	lr: 0.0001
# 	num_epochs: 5
# 	model_filename: temp/model.pth
# 	optimizer_filename: temp/optimizer.pth
# ****************************************************************************************************

# %% [markdown]
# ## Training the Tokenizer
#
# Train and save the tokenizer. This might take a few minutes to complete. But you only have to do this once as it will save the tokenizer for later use.

# %%
from pathlib import Path

if not Path(config.tokenizer_filename).exists():
  tokenizer = train_tokenizer(config)
else:
  print(f"Tokenizer already exists at {config.tokenizer_filename}")
# Out:
# Tokenizer already exists at temp/tokenizer.json

# %% [markdown]
# ## Training Your Model
#
# We use the `train_model` function from `train.py`. This will save a model (and optimizer) checkpoint after every 500 batches.
#
# When you have trained your model for around 3-5 epochs, download the model and tokenizer files to keep a copy in your local `temp` folder. You can now use these when doing inference (text generation).
#
# Note that a single epoch might take around 15-30 minutes to complete.

# %%
train_model(config)
# Out:
# Using configuration:
# 	seed: 0
# 	dataset: gooaq_subset
# 	split: train
# 	device: cuda
# 	vocab_size: 20000
# 	min_frequency: 5
# 	unk_token: [UNK]
# 	sep_token: [SEP]
# 	end_token: [END]
# 	pad_token: [PAD]
# 	tokenizer_filename: temp/tokenizer.json
# 	embed_size: 512
# 	num_heads: 8
# 	num_layers: 5
# 	dropout_p: 0.1
# 	max_len: 128
# 	model_train_fraction: 1.0
# 	batch_size: 128
# 	dataloader_num_workers: 2
# 	lr: 0.0001
# 	num_epochs: 5
# 	model_filename: temp/model.pth
# 	optimizer_filename: temp/optimizer.pth
# ****************************************************************************************************
# Number of parameters in the model: 36,261,920
# Loaded dataset of size 859765 with columns ['question', 'answer']
# [01 | 05] Loss: 4.0870: 100%|██████████| 6717/6717 [15:59<00:00,  7.00it/s]
# Mean Epoch Cross-Entropy Loss: 4.7757
# [02 | 05] Loss: 3.7301: 100%|██████████| 6717/6717 [14:30<00:00,  7.71it/s]
# Mean Epoch Cross-Entropy Loss: 3.8328
# [03 | 05] Loss: 3.4704: 100%|██████████| 6717/6717 [14:38<00:00,  7.65it/s]
# Mean Epoch Cross-Entropy Loss: 3.4875
# [04 | 05] Loss: 3.1555: 100%|██████████| 6717/6717 [13:50<00:00,  8.09it/s]
# Mean Epoch Cross-Entropy Loss: 3.2876
# [05 | 05] Loss: 3.2364: 100%|██████████| 6717/6717 [14:01<00:00,  7.98it/s]
# Mean Epoch Cross-Entropy Loss: 3.1543
# OptimizedModule(
#   (_orig_mod): TransformerModel(
#     (embedding): Embedding(20000, 512)
#     (dropout): Dropout(p=0.1, inplace=False)
#     (pos_encoder): PositionalEncoding()
#     (layers): ModuleList(
#       (0-4): 5 x DecoderBlock(
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (mlp): Sequential(
#           (0): Linear(in_features=512, out_features=2048, bias=True)
#           (1): GELU(approximate='none')
#           (2): Linear(in_features=2048, out_features=512, bias=True)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (fc_out): Linear(in_features=512, out_features=20000, bias=True)
#   )
# )
